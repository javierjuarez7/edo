# %%
import random
from matplotlib import pyplot
import matplotlib.pyplot as plt
import numpy as np

def moveenX():
    deltaX = random.randint(-100,100)
    return deltaX/100.0

def moveenY():
    deltaY = random.randint(-100,100)
    return deltaY/100.0

desplazamientoenX = []
desplazamientoenY = []
Xinicial = 0
Yinicial = 0
X = Xinicial
Y = Yinicial
counter = 0

for i in range (0,100):
    desplazamientoenX.append(X)
    desplazamientoenY.append(Y)
    X=moveenX()
    Y=moveenY()

plt.plot(desplazamientoenX, desplazamientoenY)
plt.show()
